# %% [markdown]
# ## Exemple du fonctionnement de l'algorithme de chiffrement utilisé par SEAL
# * SEAL est une librairie de chiffrement homomorphe par Microsoft
#
# https://eprint.iacr.org/2017/224.pdf
#
# * SEAL est basé sur le chiffrement BFV
#
# https://eprint.iacr.org/2012/144.pdf
#
# * Code inspiré par
#
# https://arxiv.org/pdf/1906.07127.pdf
#
# * Implémenté sur le framework Python SageMath
#
# https://www.sagemath.org

# %%
from sage.stats.distributions.discrete_gaussian_integer import DiscreteGaussianDistributionIntegerSampler

# %%
# Modulus in the ciphertext space
q = 2^35 - 2^14 + 2^11 + 1
# Modulus in the plaintext space (doit etre au moins 2x plus grand que le nombre a representer)
t = 128
# A power of 2
n = 1024
# The polynomial modulus which specifies the ring R
f = x^n + 1
# The ring Z[x]/f(x)
P.<x> = PolynomialRing(ZZ)
R.<x> = QuotientRing(P, P.ideal(f))
# Error distribution (a truncated discrete Gaussian distribution)
noise_standard_deviation = 3.20
dist = DiscreteGaussianDistributionIntegerSampler(sigma=noise_standard_deviation)
# Quotient on division of q by t
delta = floor(q / t)

# %%
def rq(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % q
    return R(coefs)

def rt(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % t
    return R(coefs)

# Cyphertext Space
def Roundq(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % q
        if coefs[i] > q / 2:
            coefs[i] = coefs[i] - q
    return R(coefs)

# Plaintext Space 
def Roundt(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % t
        if coefs[i] > t / 2:
            coefs[i] = coefs[i] - t
    return R(coefs)

# %%
assert q % (2*n) == 1
assert delta * t + rt(q) == q

# %%
# Generate a random ternary polynomial (coefs are either -1, 0 or 1)
def sample_poly_ternary():
    return R([ZZ.random_element(-1, 2, "uniform") for _ in range(n)])

# Generate a random polynomial with integer coefs from a Gaussian Distribution χ
def sample_poly_normal():
    return R([dist() for _ in range(n)])
    
# Generate a random polynomial with coefs in Z/qZ
def sample_Rq():
    return R([ZZ.random_element(0, q, "uniform") for _ in range(n)])

# %% [markdown]
# ## Génération de clé
# * Dans SEAL, la clé privé est un polynome cyclotomique

# %%
# Generate a secret key
def secretKeyGen():
    return sample_poly_ternary()

# %% [markdown]
# ### Calcule de la clé publique correspondante
# $$a \leftarrow R_q, e \leftarrow \chi$$
# $$pk = \big(-[a*s+e]_q, a\big)$$

# %%
def publicKeyGen(s):
    a = sample_Rq()
    e = sample_poly_normal()
    return [-Roundq(a * s + e), a]

# %%
sk = secretKeyGen()
pk = publicKeyGen(sk)

# %% [markdown]
# ## La fonction de chiffrement

# %%
def encrypt(p, m):
    u = sample_poly_ternary()
    e1 = sample_poly_normal()
    e2 = sample_poly_normal()
    return [Roundq(p[0] * u + e1 + delta * m), Roundq(p[1] * u + e2)]

def decrypt(s, c):
    tmp = t * Roundq(c[0] + c[1] * s)
    coefs = tmp.list()
    for i in range(len(coefs)):
        coefs[i] = round(coefs[i] / q)
    return Roundt(R(coefs))

# %%
assert decrypt(sk, encrypt(pk, 1)) == 1

# %% [markdown]
# ## Addition
# $$\Big(\big[c_1[0] + c_2[0]\big]_q , \big[c_1[1] + c_2[1]\big]_q \Big)$$

# %%
def add(c1, c2):
    return [Roundq(c1[0] + c2[0]), Roundq(c1[1] + c2[1])]

# %% [markdown]
# ### Test
# Ajoutons 20 à 22

# %%
c1 = encrypt(pk, 20)
c2 = encrypt(pk, 22)
print(decrypt(sk, add(c1, c2)))
# Out:
# 42

# %% [markdown]
# ## TODO: la multiplication
# L'algorithme de multiplication de BFV est beaucoup plus compliqué que l'addition.
# Il se fait en plusieurs étapes et nécessite des changements de bases.
#
# Voir chapitre 4 de [Somewhat Practical Fully Homomorphic Encryption](https://eprint.iacr.org/2012/144.pdf)

# %% [markdown]
# ### Exemple d'une clé privée

# %%
print(sk)
# Out:
# x^1023 - x^1022 - x^1020 + x^1019 - x^1018 + x^1015 - x^1013 + x^1011 - x^1007 + x^1006 - x^1005 + x^1003 - x^1001 + x^1000 + x^999 - x^998 + x^997 - x^996 - x^995 - x^993 - x^992 + x^991 + x^988 - x^987 + x^986 - x^985 + x^984 + x^983 - x^982 - x^981 - x^975 + x^974 + x^973 + x^972 + x^971 - x^970 - x^968 - x^966 + x^965 - x^963 - x^961 + x^960 - x^959 - x^958 + x^957 - x^955 + x^953 + x^952 - x^951 + x^950 - x^949 + x^947 + x^946 - x^945 - x^944 - x^942 + x^940 + x^939 - x^938 - x^934 + x^929 - x^925 - x^924 - x^923 + x^922 - x^921 - x^920 + x^919 + x^918 + x^917 - x^916 - x^913 - x^911 - x^910 + x^909 - x^905 - x^904 + x^903 + x^900 + x^899 + x^898 - x^897 + x^896 - x^895 + x^894 - x^892 + x^891 - x^890 + x^888 + x^887 - x^885 + x^884 - x^883 - x^882 + x^881 - x^879 + x^878 - x^877 + x^876 - x^875 - x^873 + x^872 - x^870 + x^869 - x^868 + x^867 + x^863 - x^861 + x^860 - x^859 + x^858 - x^857 + x^856 - x^855 - x^854 + x^853 - x^851 - x^848 - x^847 - x^845 - x^841 - x^840 - x^839 + x^838 - x^837 - x^836 - x^835 + x^834 + x^833 + x^832 - x^831 + x^830 + x^829 + x^828 - x^827 - x^824 - x^823 - x^822 + x^821 - x^819 + x^816 - x^815 - x^814 + x^813 - x^812 + x^810 + x^809 - x^808 + x^806 + x^803 + x^802 - x^801 - x^800 + x^795 - x^794 - x^792 + x^790 + x^788 + x^787 - x^786 - x^785 + x^784 + x^783 + x^781 - x^780 + x^779 + x^778 - x^777 + x^776 - x^775 + x^773 - x^771 - x^770 - x^768 + x^767 + x^766 + x^764 - x^763 - x^762 + x^760 - x^759 - x^758 - x^754 - x^753 - x^752 + x^751 + x^750 + x^749 + x^748 - x^747 - x^745 - x^744 - x^743 + x^740 - x^736 - x^734 + x^731 + x^730 + x^729 + x^728 - x^727 - x^726 + x^725 + x^723 - x^720 - x^719 - x^717 + x^716 - x^714 + x^713 - x^712 - x^710 + x^705 - x^704 + x^703 + x^702 - x^700 + x^699 - x^698 - x^695 - x^694 - x^693 + x^691 + x^689 - x^688 + x^687 - x^686 - x^685 + x^683 - x^682 - x^681 - x^679 + x^678 + x^677 - x^676 - x^675 + x^674 - x^673 + x^671 - x^670 - x^669 + x^668 - x^667 - x^666 + x^662 - x^660 - x^659 - x^658 - x^657 + x^656 - x^655 - x^653 + x^652 + x^651 + x^649 + x^648 + x^647 - x^646 + x^644 - x^642 - x^640 - x^639 + x^636 + x^635 + x^634 - x^633 + x^632 - x^630 - x^629 - x^628 - x^627 + x^625 - x^624 - x^623 - x^622 - x^621 + x^620 + x^619 + x^618 + x^617 + x^615 - x^612 + x^611 - x^609 - x^608 - x^606 + x^605 - x^604 - x^603 + x^602 + x^601 - x^600 - x^598 + x^596 - x^593 - x^589 - x^588 + x^586 + x^585 + x^581 - x^580 - x^579 - x^578 + x^577 - x^576 + x^575 - x^573 + x^570 - x^569 + x^567 + x^566 + x^564 - x^563 + x^562 - x^561 + x^560 + x^559 + x^558 + x^557 - x^556 - x^555 + x^554 - x^550 - x^547 + x^545 + x^544 + x^541 + x^539 - x^537 + x^536 - x^535 - x^534 + x^532 + x^531 - x^529 + x^528 - x^527 + x^526 - x^525 + x^524 - x^523 + x^520 + x^519 + x^518 - x^517 + x^515 - x^514 + x^513 - x^512 - x^511 + x^510 + x^507 - x^506 + x^505 + x^504 - x^503 - x^502 - x^501 + x^500 + x^499 + x^498 - x^496 - x^493 + x^492 + x^490 - x^488 - x^486 - x^485 - x^484 + x^483 - x^482 - x^480 - x^479 + x^477 + x^476 - x^475 + x^471 + x^467 - x^465 + x^462 - x^460 - x^458 - x^456 + x^455 - x^454 + x^453 - x^451 - x^449 + x^447 + x^444 + x^443 + x^442 - x^441 - x^440 - x^439 + x^438 - x^437 - x^436 + x^435 + x^434 - x^433 - x^432 + x^431 - x^430 + x^427 - x^426 - x^424 + x^422 + x^421 - x^420 + x^419 - x^418 - x^417 + x^415 + x^414 - x^411 + x^410 - x^408 - x^407 + x^406 - x^405 + x^401 - x^399 - x^398 + x^397 - x^396 + x^395 - x^394 - x^393 + x^392 - x^391 - x^388 - x^387 + x^386 + x^385 - x^384 - x^382 + x^381 - x^380 - x^379 - x^378 + x^375 - x^374 - x^373 - x^371 - x^369 - x^367 + x^365 - x^362 - x^361 - x^360 + x^359 - x^358 - x^357 + x^356 - x^355 + x^354 + x^352 + x^351 + x^349 + x^348 + x^347 + x^344 - x^343 - x^342 - x^341 + x^340 + x^339 - x^338 + x^337 - x^336 + x^335 + x^333 - x^332 - x^331 + x^329 - x^328 - x^326 - x^325 + x^324 + x^321 - x^320 - x^319 - x^317 + x^316 - x^315 + x^314 - x^313 + x^312 + x^310 + x^308 + x^306 - x^305 + x^304 + x^302 - x^301 - x^300 + x^299 - x^ ...

# %% [markdown]
# ### Exemple d'un nombre chiffré

# %%
print(c1)
# Out:
# [17147250508*x^1023 - 756716766*x^1022 - 15824696430*x^1021 - 16610575543*x^1020 - 1247964411*x^1019 + 14113192055*x^1018 + 11059676589*x^1017 - 8969920995*x^1016 - 13374278241*x^1015 - 7487302848*x^1014 + 2105390508*x^1013 + 1798006795*x^1012 - 346658706*x^1011 - 4053231504*x^1010 + 3344180689*x^1009 - 14973554540*x^1008 - 4088099345*x^1007 - 4860607201*x^1006 + 5663295779*x^1005 - 5101570510*x^1004 + 3366377089*x^1003 - 12468570071*x^1002 - 6042201428*x^1001 + 2266697384*x^1000 - 10738858975*x^999 - 11490152629*x^998 - 5750535948*x^997 - 12215170790*x^996 - 3321700887*x^995 + 16403279469*x^994 - 7792956074*x^993 + 4925608632*x^992 + 10481671646*x^991 - 16460862456*x^990 - 15634542189*x^989 - 15361973018*x^988 - 10196870821*x^987 - 11390992497*x^986 + 3744285145*x^985 + 160740386*x^984 - 1813799932*x^983 - 4001972037*x^982 + 6511490547*x^981 - 9915816359*x^980 - 13757552815*x^979 + 13566629350*x^978 + 16142520831*x^977 + 10674215766*x^976 + 11537210211*x^975 - 2605937722*x^974 + 9890004347*x^973 + 14353400511*x^972 - 8248696441*x^971 + 3373169426*x^970 - 418011406*x^969 + 13299584325*x^968 + 7005186673*x^967 + 4828184108*x^966 + 11435629601*x^965 - 15115517638*x^964 - 1191500645*x^963 + 1235591252*x^962 + 5594978029*x^961 + 10353055477*x^960 + 15689446835*x^959 + 2901383190*x^958 - 2047699474*x^957 + 14233489633*x^956 + 14835042227*x^955 - 7267569067*x^954 - 13118560089*x^953 + 6213025247*x^952 - 3432266275*x^951 + 12309133972*x^950 + 16816708170*x^949 - 6163805457*x^948 + 14988469951*x^947 + 16602836221*x^946 + 12893113746*x^945 + 13891629097*x^944 - 10516694515*x^943 - 12486277082*x^942 + 13772608566*x^941 + 16444385055*x^940 - 14115056003*x^939 + 1736679365*x^938 - 14882898272*x^937 + 14878939806*x^936 + 13177933079*x^935 - 6977278867*x^934 + 16128745483*x^933 + 16198572584*x^932 - 3945610419*x^931 - 13780563629*x^930 - 13417253927*x^929 + 6195048862*x^928 + 5703309202*x^927 - 14740640754*x^926 + 194836645*x^925 - 9134585409*x^924 - 13642687439*x^923 - 7285851147*x^922 + 4664299720*x^921 - 4722135251*x^920 + 9568619279*x^919 + 8562784080*x^918 - 1021832215*x^917 + 1239891883*x^916 + 7557678778*x^915 + 3824750995*x^914 - 15899042402*x^913 - 12665661782*x^912 - 9356651435*x^911 - 1509393330*x^910 + 15966371561*x^909 + 10645272617*x^908 - 2935040763*x^907 + 15494960195*x^906 + 12352036314*x^905 + 15102845553*x^904 + 7889606828*x^903 - 4512227666*x^902 + 10291007111*x^901 - 16302224210*x^900 + 16933598603*x^899 + 10812263843*x^898 + 8091582056*x^897 + 946576465*x^896 - 10853563255*x^895 - 10392508071*x^894 - 9446181212*x^893 - 8956476590*x^892 - 9035677760*x^891 + 8444588862*x^890 - 14196856446*x^889 + 2220350770*x^888 + 1439637426*x^887 - 3332752125*x^886 - 12952187412*x^885 - 15730130979*x^884 + 14840253430*x^883 + 1749367973*x^882 - 2400129967*x^881 + 6370145616*x^880 - 10544560103*x^879 - 573747114*x^878 + 4604672889*x^877 - 11175226187*x^876 + 11948793298*x^875 + 4924091098*x^874 - 3561668318*x^873 - 2728840198*x^872 + 8101948293*x^871 - 6358194532*x^870 + 16458945312*x^869 - 11735753904*x^868 + 13924409776*x^867 + 2452743188*x^866 + 6663708333*x^865 + 1551251583*x^864 + 9025352855*x^863 + 16611295046*x^862 - 8199627212*x^861 - 1351295276*x^860 + 11237650452*x^859 - 508359748*x^858 - 5219984746*x^857 - 4906444286*x^856 + 11511549554*x^855 - 8001696903*x^854 + 1405127842*x^853 - 16606788427*x^852 - 2372668795*x^851 - 823050363*x^850 - 7814529411*x^849 + 81244574*x^848 + 5446161641*x^847 - 16927958568*x^846 + 15847741826*x^845 - 1187153647*x^844 - 6727153728*x^843 - 6920019084*x^842 - 1866006333*x^841 - 4897474090*x^840 + 3876654002*x^839 + 4777924954*x^838 + 8497030512*x^837 + 8289314389*x^836 - 7177010716*x^835 - 4553944147*x^834 + 2545305670*x^833 + 2349001873*x^832 + 189974146*x^831 - 15036066119*x^830 + 5792905426*x^829 - 6787359747*x^828 + 7620618346*x^827 + 10221189176*x^826 - 1281624385*x^825 + 4160129504*x^824 - 4910891367*x^823 + 11133557465*x^822 - 6518145521*x^821 - 10328135131*x^820 - 4014764971*x^819 + 4164009 ...
