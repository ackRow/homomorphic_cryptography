# %% [markdown]
# ## Exemple du fonctionnement de l'algorithme de chiffrement utilisé par SEAL
# * SEAL est une librairie de chiffrement homomorphe par Microsoft
#
# https://eprint.iacr.org/2017/224.pdf
#
# * SEAL est basé sur le chiffrement BFV
#
# https://eprint.iacr.org/2012/144.pdf
#
# * Code inspiré par
#
# https://arxiv.org/pdf/1906.07127.pdf
#
# * Implémenté sur le framework Python SageMath
#
# https://www.sagemath.org

# %%
from sage.stats.distributions.discrete_gaussian_integer import DiscreteGaussianDistributionIntegerSampler

# %%
# Modulus in the ciphertext space
q = 2^35 - 2^14 + 2^11 + 1
# Modulus in the plaintext space (doit etre au moins 2x plus grand que le nombre a representer)
t = 128
# A power of 2
n = 1024
# The polynomial modulus which specifies the ring R
f = x^n + 1
# The ring Z[x]/f(x)
P.<x> = PolynomialRing(ZZ)
R.<x> = QuotientRing(P, P.ideal(f))
# Error distribution (a truncated discrete Gaussian distribution)
noise_standard_deviation = 3.20
dist = DiscreteGaussianDistributionIntegerSampler(sigma=noise_standard_deviation)
# Quotient on division of q by t
delta = floor(q / t)

# %%
def rq(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % q
    return R(coefs)

def rt(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % t
    return R(coefs)

# Cyphertext Space
def Roundq(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % q
        if coefs[i] > q / 2:
            coefs[i] = coefs[i] - q
    return R(coefs)

# Plaintext Space 
def Roundt(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % t
        if coefs[i] > t / 2:
            coefs[i] = coefs[i] - t
    return R(coefs)

# %%
assert q % (2*n) == 1
assert delta * t + rt(q) == q

# %%
# Generate a random ternary polynomial (coefs are either -1, 0 or 1)
def sample_poly_ternary():
    return R([ZZ.random_element(-1, 2, "uniform") for _ in range(n)])

# Generate a random polynomial with integer coefs from a Gaussian Distribution χ
def sample_poly_normal():
    return R([dist() for _ in range(n)])
    
# Generate a random polynomial with coefs in Z/qZ
def sample_Rq():
    return R([ZZ.random_element(0, q - 1, "uniform") for _ in range(n)])

# %% [markdown]
# ## Génération de clé
# * Dans SEAL, la clé privé est un polynome cyclotomique

# %%
# Generate a secret key
def secretKeyGen():
    return sample_poly_ternary()

# %% [markdown]
# ### Calcule de la clé publique correspondante
# $$a \leftarrow R_q, e \leftarrow \chi$$
# $$pk = \big(-[a*s+e]_q, a\big)$$

# %%
def publicKeyGen(s):
    a = sample_Rq()
    e = sample_poly_normal()
    return [-Roundq(a * s + e), a]

# %%
sk = secretKeyGen()
pk = publicKeyGen(sk)

# %% [markdown]
# ## La fonction de chiffrement

# %%
def encrypt(p, m):
    u = sample_poly_ternary()
    e1 = sample_poly_normal()
    e2 = sample_poly_normal()
    return [Roundq(p[0] * u + e1 + delta * m), Roundq(p[1] * u + e2)]

def decrypt(s, c):
    tmp = t * Roundq(c[0] + c[1] * s)
    coefs = tmp.list()
    for i in range(len(coefs)):
        coefs[i] = round(coefs[i] / q)
    return Roundt(R(coefs))

# %%
assert decrypt(sk, encrypt(pk, 1)) == 1

# %% [markdown]
# ## Addition
# $$\Big(\big[c_1[0] + c_2[0]\big]_q , \big[c_1[1] + c_2[1]\big]_q \Big)$$

# %%
def add(c1, c2):
    return [Roundq(c1[0] + c2[0]), Roundq(c1[1] + c2[1])]

# %% [markdown]
# ### Test
# Ajoutons 20 à 22

# %%
c1 = encrypt(pk, 20)
c2 = encrypt(pk, 22)
print(decrypt(sk, add(c1, c2)))
# Out:
# 42

# %% [markdown]
# ## TODO: la multiplication
# L'algorithme de multiplication de BFV est beaucoup plus compliqué que l'addition.
# Il se fait en plusieurs étapes et nécessite des changements de bases.
#
# Voir chapitre 4 de [Somewhat Practical Fully Homomorphic Encryption](https://eprint.iacr.org/2012/144.pdf)

# %% [markdown]
# ### Exemple d'une clé privée

# %%
print(sk)
# Out:
# x^1019 + x^1016 - x^1014 - x^1013 - x^1012 + x^1011 - x^1009 + x^1008 - x^1007 - x^1006 - x^1005 + x^1004 + x^1003 - x^1002 - x^1000 - x^999 + x^998 + x^995 - x^994 + x^992 - x^991 + x^990 - x^989 + x^988 - x^986 + x^985 + x^982 - x^980 - x^978 + x^977 + x^975 - x^974 - x^972 + x^971 + x^969 - x^968 + x^967 + x^966 - x^964 - x^963 - x^962 - x^961 + x^960 - x^959 - x^958 - x^955 + x^953 - x^952 + x^950 - x^947 + x^945 - x^943 - x^942 - x^938 + x^937 + x^936 + x^935 + x^934 - x^933 - x^929 + x^928 + x^926 + x^925 + x^923 + x^922 - x^919 - x^918 - x^917 - x^916 - x^915 - x^914 - x^913 + x^912 - x^911 + x^908 - x^907 - x^906 - x^905 + x^904 + x^903 + x^902 - x^901 - x^900 - x^898 + x^897 - x^896 + x^895 + x^894 - x^892 + x^890 - x^889 - x^888 - x^887 + x^886 - x^883 + x^881 + x^880 + x^879 + x^878 + x^877 - x^876 - x^875 + x^873 - x^872 - x^871 - x^869 + x^868 + x^867 + x^866 + x^865 - x^864 + x^863 - x^862 + x^861 - x^860 - x^859 - x^858 - x^857 + x^856 - x^855 + x^853 + x^851 + x^850 + x^849 + x^846 - x^845 - x^844 - x^843 - x^841 - x^837 + x^835 + x^834 + x^832 - x^830 - x^829 + x^828 - x^825 - x^822 + x^821 - x^820 + x^818 - x^817 - x^815 - x^813 - x^811 - x^809 - x^808 + x^806 + x^804 + x^803 - x^802 - x^801 - x^799 - x^797 + x^796 + x^795 + x^794 - x^791 - x^788 - x^786 + x^785 + x^784 - x^782 + x^781 + x^780 - x^779 + x^777 + x^775 + x^773 - x^772 - x^771 - x^770 + x^769 - x^768 + x^767 + x^764 - x^763 + x^762 - x^761 - x^759 + x^756 + x^755 - x^754 + x^753 + x^752 - x^751 - x^750 - x^747 + x^745 - x^744 - x^743 + x^742 + x^740 + x^739 + x^735 - x^732 - x^731 - x^730 - x^728 - x^725 + x^723 + x^722 - x^721 - x^718 - x^717 - x^716 - x^715 + x^714 - x^711 + x^709 - x^708 + x^707 - x^706 - x^705 + x^704 - x^703 - x^701 - x^699 + x^698 + x^696 - x^695 - x^694 + x^692 + x^690 + x^689 - x^687 - x^686 + x^685 + x^684 + x^683 - x^682 - x^679 - x^678 - x^675 - x^674 + x^673 - x^672 - x^671 - x^670 + x^669 + x^666 - x^664 + x^663 + x^662 + x^661 + x^659 - x^657 + x^656 + x^655 - x^654 - x^653 - x^651 - x^650 - x^649 + x^646 + x^644 + x^642 - x^641 - x^640 - x^639 - x^635 - x^634 - x^633 - x^632 - x^631 - x^630 - x^626 + x^624 - x^623 - x^621 - x^620 - x^616 - x^614 - x^613 - x^612 + x^611 + x^610 - x^609 - x^605 + x^604 + x^600 - x^599 - x^598 - x^597 + x^596 + x^593 + x^591 + x^590 + x^589 + x^587 - x^586 - x^585 + x^583 + x^582 + x^581 - x^579 + x^578 + x^574 - x^573 - x^570 + x^569 - x^568 + x^567 - x^566 + x^564 - x^563 - x^562 + x^561 + x^560 - x^559 - x^556 + x^555 - x^554 + x^553 - x^552 + x^551 - x^550 - x^549 + x^548 + x^547 + x^545 - x^543 - x^542 - x^540 - x^539 - x^538 - x^537 + x^535 + x^533 - x^532 + x^530 + x^527 - x^525 + x^524 + x^523 - x^521 + x^520 + x^519 - x^518 - x^516 + x^511 - x^510 + x^506 + x^505 - x^502 - x^501 + x^500 - x^499 + x^497 - x^496 + x^494 - x^493 + x^492 + x^490 + x^488 + x^486 - x^485 - x^484 + x^482 - x^481 - x^478 - x^475 + x^473 - x^469 + x^468 - x^467 + x^465 + x^464 + x^463 - x^462 + x^458 + x^457 + x^456 - x^455 + x^454 - x^453 + x^452 + x^451 - x^450 + x^448 - x^447 - x^446 + x^445 - x^442 - x^439 - x^437 + x^436 + x^435 + x^434 - x^433 - x^432 - x^431 - x^429 - x^428 + x^426 - x^425 + x^423 + x^422 - x^421 - x^420 + x^419 + x^418 - x^417 - x^416 - x^414 - x^412 + x^411 + x^410 - x^409 + x^408 + x^407 + x^406 - x^405 - x^403 - x^401 - x^400 + x^399 - x^398 + x^394 - x^391 - x^390 + x^389 + x^388 - x^387 + x^386 - x^385 + x^384 + x^383 + x^381 - x^380 - x^378 - x^377 - x^376 - x^375 - x^372 - x^371 - x^370 + x^366 + x^364 + x^363 + x^362 - x^361 - x^360 - x^359 - x^358 + x^356 - x^355 - x^354 + x^352 - x^350 - x^348 + x^346 - x^345 + x^344 - x^342 - x^341 + x^339 + x^338 + x^337 + x^336 + x^333 + x^332 + x^330 - x^328 + x^327 - x^323 + x^321 + x^319 + x^318 + x^317 + x^315 - x^311 - x^308 - x^304 - x^303 + x^302 + x^301 - x^299 + x^297 - x^296 + x^295 + x^294 + x^293 - x^291 + x^290 + x^289 - x^287 + x^286 - x^284 - x^282 - x^281 - x^280 - x^279 + x^276 + x^275 + x^274 + x^273 + x^272 - x ...

# %% [markdown]
# ### Exemple d'un nombre chiffré

# %%
print(c1)
# Out:
# [3932394031*x^1023 + 13850043939*x^1022 + 15333543911*x^1021 - 11418990717*x^1020 - 282377970*x^1019 - 2008384493*x^1018 - 11037949409*x^1017 - 8515658308*x^1016 + 13993320670*x^1015 - 13932354111*x^1014 + 3507859338*x^1013 + 1162945935*x^1012 + 5579883608*x^1011 + 12832073749*x^1010 + 3026975384*x^1009 - 8747649814*x^1008 - 5879871867*x^1007 - 11510458202*x^1006 + 383019832*x^1005 - 11918237527*x^1004 + 13060102000*x^1003 + 7817384427*x^1002 - 13628019149*x^1001 - 423123457*x^1000 - 7075655851*x^999 - 11885889916*x^998 + 3980561357*x^997 - 808849558*x^996 + 10680856227*x^995 - 12141212752*x^994 - 1940702843*x^993 - 13638291921*x^992 + 1341633742*x^991 - 17093256573*x^990 + 5719913575*x^989 - 16567704237*x^988 - 16607553417*x^987 + 16127937376*x^986 - 15128570970*x^985 + 14706026370*x^984 - 2856590854*x^983 - 15146164843*x^982 + 12327481570*x^981 - 292515343*x^980 + 12635373688*x^979 + 12873004762*x^978 - 12393350311*x^977 - 14632215405*x^976 - 5583237572*x^975 + 10241471567*x^974 + 6250292859*x^973 + 4237971080*x^972 + 6099222853*x^971 + 10289840137*x^970 + 15876274734*x^969 - 2786583853*x^968 - 14549343701*x^967 + 4823081248*x^966 + 1755318880*x^965 + 6269966400*x^964 - 15759457286*x^963 + 9155541471*x^962 - 11988236557*x^961 - 5303614673*x^960 - 639853072*x^959 + 2460569150*x^958 + 3352055937*x^957 + 389659321*x^956 + 13844803225*x^955 + 8403195200*x^954 - 13687944743*x^953 - 9026153788*x^952 + 14118843377*x^951 + 4660549492*x^950 - 3606796801*x^949 - 5474828966*x^948 - 11432517979*x^947 - 12574351161*x^946 - 11907300678*x^945 + 3417806880*x^944 - 10727860209*x^943 - 7657209831*x^942 + 9998611181*x^941 + 15904939656*x^940 - 102955700*x^939 - 9956267391*x^938 + 5110139517*x^937 + 5022645101*x^936 - 11372970245*x^935 + 10767692738*x^934 + 13471056785*x^933 + 4405933388*x^932 - 4728173286*x^931 - 12420636568*x^930 + 1954103158*x^929 + 9463667745*x^928 - 14215733830*x^927 + 3113344613*x^926 - 14639053653*x^925 + 11302191393*x^924 - 12128666201*x^923 + 13069162366*x^922 - 14734740755*x^921 + 10631030261*x^920 - 4233037988*x^919 - 10422515159*x^918 + 6969700311*x^917 + 9273112604*x^916 - 1812882753*x^915 - 15845299405*x^914 + 13271625914*x^913 - 13363248645*x^912 - 3166051843*x^911 - 11052513656*x^910 - 15467919702*x^909 + 6586722361*x^908 - 16408175902*x^907 - 4919878412*x^906 + 7614262978*x^905 + 699388103*x^904 - 10224355352*x^903 + 13045501653*x^902 + 7771721328*x^901 + 4343585206*x^900 + 11976594862*x^899 - 16354025760*x^898 + 303492660*x^897 - 7123189439*x^896 + 13279487958*x^895 + 7812153776*x^894 + 3213886968*x^893 - 12952216444*x^892 + 1665329172*x^891 + 286808316*x^890 + 16953549867*x^889 - 5022772166*x^888 - 13260482577*x^887 - 7561364853*x^886 + 4488741783*x^885 + 11324696532*x^884 + 15001079351*x^883 - 12422256225*x^882 - 2019147237*x^881 - 2597541441*x^880 - 14173151015*x^879 - 8547867357*x^878 + 8625327834*x^877 + 5269562275*x^876 + 14283096734*x^875 + 11051130337*x^874 - 2260570375*x^873 + 2467330014*x^872 - 2175402335*x^871 - 7838030825*x^870 + 14389225198*x^869 - 5808243777*x^868 + 9591934441*x^867 - 5352084874*x^866 + 13147140798*x^865 + 11298076404*x^864 + 8043011381*x^863 + 1542848684*x^862 - 11899943852*x^861 - 4293017120*x^860 + 409113735*x^859 - 3451845262*x^858 + 11355897182*x^857 + 12756725986*x^856 + 5601662456*x^855 + 10565381602*x^854 - 7565982672*x^853 - 13192624499*x^852 + 7803117040*x^851 - 12173682260*x^850 + 15561252706*x^849 + 5765052707*x^848 - 5704009464*x^847 + 11128044561*x^846 - 3034375474*x^845 - 16679531482*x^844 + 12820127051*x^843 + 9371247864*x^842 - 16701443442*x^841 + 11861983532*x^840 + 4757614640*x^839 - 9897018617*x^838 - 9449993241*x^837 - 15059388611*x^836 + 2489392117*x^835 - 5698920177*x^834 + 12003377322*x^833 - 1083176596*x^832 + 15746943749*x^831 + 5683311597*x^830 + 8625966013*x^829 - 16043759781*x^828 - 13296019779*x^827 - 14713170580*x^826 - 7444693680*x^825 - 7604560646*x^824 - 12498964072*x^823 + 2227911327*x^822 - 3343084958*x^821 - 6775077746*x^820 + 8876838201*x^819 ...
