# %% [markdown]
# ## Exemple du fonctionnement de l'algorithme de chiffrement utilisé par SEAL
# * SEAL est une librairie de chiffrement homomorphe par Microsoft
#
# https://eprint.iacr.org/2017/224.pdf
#
# * SEAL est basé sur le chiffrement BFV
#
# https://eprint.iacr.org/2012/144.pdf
#
# * Code inspiré par
#
# https://arxiv.org/pdf/1906.07127.pdf
#
# * Implémenté sur le framework Python SageMath
#
# https://www.sagemath.org

# %%
from sage.stats.distributions.discrete_gaussian_integer import DiscreteGaussianDistributionIntegerSampler

# %%
# Modulus in the ciphertext space
q = 2^35 - 2^14 + 2^11 + 1
# Modulus in the plaintext space (doit etre au moins 2x plus grand que le nombre a representer)
t = 128
# A power of 2
n = 1024
# The polynomial modulus which specifies the ring R
f = x^n + 1
# The ring Z[x]/f(x)
P.<x> = PolynomialRing(ZZ)
R.<x> = QuotientRing(P, P.ideal(f))
# Error distribution (a truncated discrete Gaussian distribution)
noise_standard_deviation = 3.20
dist = DiscreteGaussianDistributionIntegerSampler(sigma=noise_standard_deviation)
# Quotient on division of q by t
delta = floor(q / t)

# %%
def rq(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % q
    return R(coefs)

def rt(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % t
    return R(coefs)

# Cyphertext Space
def Roundq(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % q
        if coefs[i] > q / 2:
            coefs[i] = coefs[i] - q
    return R(coefs)

# Plaintext Space 
def Roundt(poly):
    coefs = poly.list()
    for i in range(len(coefs)):
        coefs[i] = coefs[i] % t
        if coefs[i] > t / 2:
            coefs[i] = coefs[i] - t
    return R(coefs)

# %%
assert q % (2*n) == 1
assert delta * t + rt(q) == q

# %%
# Generate a random ternary polynomial (coefs are either -1, 0 or 1)
def sample_poly_ternary():
    return R([ZZ.random_element(-1, 2, "uniform") for _ in range(n)])

# Generate a random polynomial with integer coefs from a Gaussian Distribution χ
def sample_poly_normal():
    return R([dist() for _ in range(n)])
    
# Generate a random polynomial with coefs in Z/qZ
def sample_Rq():
    return R([ZZ.random_element(0, q, "uniform") for _ in range(n)])

# %% [markdown]
# ## Génération de clé
# * Dans SEAL, la clé privé est un polynome cyclotomique

# %%
def secretKeyGen():
    return sample_poly_ternary()

# %% [markdown]
# ### Calcule de la clé publique correspondante
# $$a \leftarrow R_q, e \leftarrow \chi$$
# $$pk = \big(-[a*s+e]_q, a\big)$$

# %%
def publicKeyGen(s):
    a = sample_Rq()
    e = sample_poly_normal()
    return [-Roundq(a * s + e), a]

# %%
sk = secretKeyGen()
pk = publicKeyGen(sk)

# %% [markdown]
# ## La fonction de chiffrement
# $$c = \big([p_0 * u + e_1 + \Delta * m]_q, [p_1 * u + e_2]_q\big)$$

# %%
def encrypt(p, m):
    u = sample_poly_ternary()
    e1 = sample_poly_normal()
    e2 = sample_poly_normal()
    return [Roundq(p[0] * u + e1 + delta * m), Roundq(p[1] * u + e2)]

def decrypt(s, c):
    tmp = t * Roundq(c[0] + c[1] * s)
    coefs = tmp.list()
    for i in range(len(coefs)):
        coefs[i] = round(coefs[i] / q)
    return Roundt(R(coefs))

# %%
assert decrypt(sk, encrypt(pk, 1)) == 1

# %% [markdown]
# # Opérations entre message chiffrées
# $(c_1,c_2) \in C$,
# $$c_1 \oplus c_2$$
# ## Addition
# $$\Big(\big[c_1[0] + c_2[0]\big]_q , \big[c_1[1] + c_2[1]\big]_q \Big)$$

# %%
def add(c1, c2):
    return [Roundq(c1[0] + c2[0]), Roundq(c1[1] + c2[1])]

# %% [markdown]
# ### Test
# Ajoutons 20 à 22

# %%
c1 = encrypt(pk, 20)
c2 = encrypt(pk, 22)
print(decrypt(sk, add(c1, c2)))
# Out:
# 42

# %% [markdown]
# ## TODO: la multiplication
# L'algorithme de multiplication de BFV est beaucoup plus compliqué que l'addition.
# Il se fait en plusieurs étapes et nécessite des changements de bases.
#
# Voir chapitre 4 de [Somewhat Practical Fully Homomorphic Encryption](https://eprint.iacr.org/2012/144.pdf)

# %% [markdown]
# # Opérations entre un message chiffrée et un message en clair
# Très utilisé dans CryptoNets https://www.microsoft.com/en-us/research/wp-content/uploads/2016/04/CryptonetsTechReport.pdf
#
# $c_1 \in C, m_2 \in M,$
# $$c_1 \oplus m_2$$
#
# * Intuitivement, on pourrait chiffrer le message $m_1$ avant d'appliquer l'opération mais ce n'est pas très performant
# * Ce genre d'opération est utile dans un réseau de neurones, par exemple lors du produit des poids (non chiffrés) avec l'image de l'utilisateur (chiffrée)
#
# ## Addition
# $$c_1[0] + m_2 * \Delta = [p_0 * u + e_1 + \Delta * (m_1 + m_2)]_q $$

# %%
def add_plain(c1, m2):
    return [Roundq(c1[0] + delta * m2), c1[1]]

# %% [markdown]
# J'ajoute 20 chiffré à 1

# %%
print(decrypt(sk, add_plain(c1, 1)))
# Out:
# 21

# %% [markdown]
# ## Multiplication
# $$c_1 * m_2 = \big([p_0 * u' + e_1' + \Delta * m_1 * m_2]_q, [p_1*u'+e_2']_q\big)$$

# %%
def mult_plain(c1, m2):
    return [Roundq(c1[0] * m2), Roundq(c1[1] * m2)]

# %% [markdown]
# Je multiplie 20 chiffré par 2

# %%
print(decrypt(sk, mult_plain(c1, 2)))
# Out:
# 40

# %% [markdown]
# ## Fonction
# On peut donc appliquer des fonctions à nos données
#
# Par exemple on va appliquer $f(x) = 2x+2$ à 20 chiffré

# %%
def f(c):
    return add_plain(mult_plain(c, 2), 2)

# %%
print(decrypt(sk, f(c1)))
# Out:
# 42

# %% [markdown]
# ### Exemple d'une clé privée

# %%
print(sk)
# Out:
# x^1022 + x^1020 - x^1018 + x^1017 + x^1016 - x^1014 - x^1013 + x^1012 - x^1011 + x^1010 + x^1007 + x^1006 - x^1005 - x^1004 + x^1003 - x^1002 + x^1001 - x^1000 + x^999 - x^998 + x^997 + x^996 - x^995 + x^994 + x^993 + x^992 + x^991 + x^990 - x^989 - x^988 + x^987 + x^986 + x^985 - x^984 - x^983 - x^981 - x^979 - x^978 + x^977 + x^976 - x^975 - x^971 - x^969 - x^968 + x^965 + x^963 - x^962 + x^960 - x^959 - x^957 - x^956 - x^955 + x^954 + x^953 - x^951 + x^950 + x^949 - x^947 - x^946 + x^945 - x^944 + x^943 - x^942 + x^941 + x^939 - x^935 + x^934 - x^930 - x^927 + x^924 - x^923 - x^922 - x^921 - x^917 - x^916 - x^915 - x^913 + x^912 - x^910 + x^909 + x^908 - x^907 - x^906 + x^905 + x^904 - x^903 - x^902 + x^901 - x^900 - x^899 + x^897 - x^896 + x^894 - x^893 + x^892 + x^891 + x^889 + x^888 - x^885 - x^882 + x^881 + x^880 + x^878 - x^877 + x^876 - x^875 + x^874 + x^870 + x^869 + x^867 + x^866 + x^865 - x^864 + x^862 - x^861 + x^860 + x^858 - x^856 + x^855 + x^854 + x^850 + x^849 + x^848 - x^847 - x^846 - x^845 - x^844 + x^843 - x^842 - x^841 - x^838 - x^837 - x^836 + x^835 + x^831 + x^829 - x^828 - x^826 - x^824 + x^823 + x^821 + x^820 - x^819 - x^818 - x^816 - x^812 - x^811 + x^810 + x^806 - x^805 + x^803 - x^802 - x^801 + x^800 + x^799 - x^797 - x^796 + x^795 - x^794 - x^793 + x^792 - x^791 + x^790 + x^789 + x^786 - x^785 - x^784 - x^782 - x^780 - x^779 - x^778 + x^777 - x^776 + x^773 + x^772 + x^771 + x^770 + x^769 + x^768 + x^767 - x^766 - x^764 + x^763 + x^762 + x^761 - x^759 + x^758 - x^757 + x^756 + x^754 - x^753 - x^750 + x^749 + x^748 - x^747 + x^746 + x^745 + x^744 - x^741 - x^740 - x^739 + x^738 + x^737 + x^736 + x^735 + x^734 - x^733 + x^732 - x^731 - x^729 + x^728 + x^727 - x^726 - x^724 - x^723 - x^722 - x^721 - x^720 - x^718 - x^716 - x^713 + x^712 - x^710 - x^708 - x^707 - x^705 + x^704 + x^702 + x^700 + x^698 - x^696 - x^694 - x^693 + x^692 + x^691 + x^690 + x^689 + x^688 + x^687 - x^686 + x^684 - x^683 - x^681 + x^677 + x^676 + x^675 + x^672 + x^670 + x^669 - x^667 - x^666 + x^665 - x^664 + x^659 + x^658 + x^657 - x^656 - x^655 + x^654 - x^653 - x^652 + x^651 + x^650 + x^649 - x^648 - x^647 - x^646 - x^645 + x^644 + x^642 - x^639 - x^636 + x^635 + x^634 + x^631 - x^630 - x^629 + x^628 + x^626 - x^625 + x^623 - x^622 - x^621 + x^620 + x^619 + x^618 + x^617 - x^616 + x^613 + x^611 - x^610 - x^609 + x^608 - x^606 + x^604 + x^603 + x^602 + x^601 + x^600 - x^599 + x^598 - x^596 - x^595 + x^594 + x^591 - x^589 + x^588 - x^587 - x^586 + x^585 - x^582 - x^579 + x^578 - x^577 + x^575 + x^574 + x^573 - x^569 + x^568 - x^567 - x^566 + x^565 - x^564 - x^562 + x^561 - x^560 + x^558 + x^557 + x^555 - x^553 + x^550 - x^549 - x^548 + x^547 + x^546 - x^545 + x^542 + x^538 - x^537 + x^536 + x^535 - x^534 - x^531 - x^528 + x^525 + x^524 - x^523 - x^522 - x^520 - x^519 - x^518 - x^517 + x^514 + x^512 + x^510 - x^509 - x^508 - x^506 + x^505 + x^504 + x^502 + x^501 + x^500 + x^499 + x^498 + x^497 + x^494 + x^492 + x^490 + x^489 - x^488 - x^487 + x^486 - x^484 - x^483 + x^482 + x^480 - x^479 - x^478 - x^477 - x^475 - x^474 - x^473 + x^472 - x^469 + x^468 - x^467 + x^465 - x^463 - x^462 - x^461 + x^460 - x^457 - x^453 - x^452 - x^451 + x^446 + x^445 - x^444 - x^443 + x^442 - x^441 - x^440 + x^439 + x^438 + x^437 - x^436 - x^435 + x^434 - x^433 + x^432 + x^431 + x^426 + x^425 - x^423 - x^422 - x^420 - x^418 + x^414 - x^412 - x^410 + x^409 + x^407 + x^405 + x^403 + x^400 - x^399 - x^397 + x^396 - x^395 + x^394 + x^392 - x^390 + x^388 + x^387 - x^385 + x^384 + x^383 + x^381 - x^378 + x^377 + x^376 - x^375 + x^374 + x^373 + x^372 + x^371 - x^370 + x^369 + x^368 + x^367 - x^366 + x^364 + x^363 + x^362 - x^361 + x^360 - x^359 + x^358 - x^357 - x^355 + x^354 - x^353 - x^352 - x^351 + x^349 + x^347 + x^346 - x^345 + x^344 + x^339 - x^338 + x^337 - x^336 - x^334 - x^333 + x^331 + x^330 + x^329 + x^328 + x^327 + x^326 + x^324 + x^321 - x^320 + x^316 - x^314 + x^313 + x^312 - x^311 + x^309 + x^308 + x^305 + x^304 - x^300 + x^299 - x^298 - x^296  ...

# %% [markdown]
# ### Exemple d'un nombre chiffré

# %%
print(c1)
# Out:
# [-11425718130*x^1023 - 4403920575*x^1022 + 8653998140*x^1021 + 15620674161*x^1020 + 10610571732*x^1019 - 12402248220*x^1018 - 12801808272*x^1017 + 2282424072*x^1016 - 13056153525*x^1015 - 2067942570*x^1014 + 7424887003*x^1013 + 8240605065*x^1012 - 8105575718*x^1011 - 8975213868*x^1010 - 3020716518*x^1009 - 14040024181*x^1008 - 16875581142*x^1007 - 11161522006*x^1006 + 11136250960*x^1005 + 7271666334*x^1004 + 6215628079*x^1003 + 9621705108*x^1002 + 3814733096*x^1001 - 2069547894*x^1000 - 15941645707*x^999 + 9620195070*x^998 + 12043532624*x^997 - 15381153300*x^996 - 16809986419*x^995 - 9778527897*x^994 + 2686748803*x^993 - 9491005373*x^992 + 9829423179*x^991 + 14645385020*x^990 - 3321015876*x^989 - 14501237472*x^988 + 4067244549*x^987 + 7001945960*x^986 - 13272068115*x^985 - 5638451057*x^984 - 7837359660*x^983 - 4665228945*x^982 - 1886428363*x^981 - 6966933080*x^980 - 5555721668*x^979 - 12080607450*x^978 + 9078319851*x^977 - 15966302106*x^976 + 11141816955*x^975 - 8691861080*x^974 + 9398625572*x^973 - 12634252289*x^972 + 4295190284*x^971 - 16173317787*x^970 - 15028646975*x^969 - 8987584779*x^968 + 1096142044*x^967 + 16722086653*x^966 + 11326561960*x^965 - 244071804*x^964 + 2913515735*x^963 + 11972450386*x^962 + 2490198388*x^961 - 12997769915*x^960 + 920010665*x^959 + 2554807742*x^958 + 9697763507*x^957 - 11669801337*x^956 - 11483046567*x^955 + 12655676352*x^954 + 15933507238*x^953 + 15312418834*x^952 + 13286558929*x^951 - 2900596464*x^950 + 4329473459*x^949 + 10167748404*x^948 + 649822252*x^947 + 15953207956*x^946 - 16686453349*x^945 - 11649549106*x^944 - 5184481862*x^943 - 3771223255*x^942 - 12848371700*x^941 + 11561972440*x^940 - 1631442318*x^939 + 766933285*x^938 + 9618396666*x^937 - 12078533524*x^936 - 3793325646*x^935 + 217231263*x^934 - 13158087925*x^933 + 1039571092*x^932 - 10397136362*x^931 + 13007823273*x^930 - 14975741493*x^929 + 6900655270*x^928 + 2459336227*x^927 - 6017051897*x^926 + 13004457346*x^925 + 6093520101*x^924 + 11360283584*x^923 + 10835496835*x^922 - 3941250187*x^921 - 3767981926*x^920 - 15030649306*x^919 + 4163005946*x^918 + 16657184853*x^917 - 2868708720*x^916 + 415112028*x^915 - 16567784353*x^914 + 981244614*x^913 - 13680448872*x^912 + 6226440650*x^911 - 11596159908*x^910 + 7546298473*x^909 + 12752878856*x^908 - 14153800192*x^907 - 7847287863*x^906 + 16189763989*x^905 + 14702607263*x^904 + 13859862357*x^903 + 8349211355*x^902 + 6278194649*x^901 + 11000838412*x^900 - 9460801340*x^899 + 8208822197*x^898 + 6727539332*x^897 + 4327688319*x^896 - 9914525582*x^895 + 10244864610*x^894 + 9956475149*x^893 - 1388938642*x^892 + 14715454681*x^891 + 767880150*x^890 + 7941731530*x^889 - 461477813*x^888 + 13307478637*x^887 - 10586501829*x^886 + 1059010644*x^885 - 10691741766*x^884 + 8997529593*x^883 + 3517828515*x^882 + 5877845733*x^881 + 2260863026*x^880 + 15764609600*x^879 + 2232035634*x^878 - 5047854275*x^877 - 10516053517*x^876 + 5544728562*x^875 + 2713210905*x^874 + 12671499188*x^873 + 9743481484*x^872 + 13408359873*x^871 - 5562517146*x^870 - 9611191074*x^869 + 5337708033*x^868 - 5266055616*x^867 + 9771584438*x^866 + 11237439504*x^865 - 15877245637*x^864 - 1909075665*x^863 + 2420817728*x^862 - 12846953992*x^861 + 8230802539*x^860 + 15629054531*x^859 - 13418219601*x^858 + 7852808515*x^857 + 13124823976*x^856 - 7071157600*x^855 + 6583630704*x^854 - 14111566950*x^853 - 8196304802*x^852 - 1953449978*x^851 - 3133370126*x^850 + 12062629126*x^849 + 6740704329*x^848 + 12462511443*x^847 - 12457657323*x^846 + 5488296874*x^845 + 4628587751*x^844 + 6989413841*x^843 + 11968144877*x^842 + 10890911743*x^841 - 5414532280*x^840 - 3737259420*x^839 - 11172915680*x^838 - 8929868065*x^837 - 14133867890*x^836 + 5314567376*x^835 - 10011004062*x^834 - 16406264256*x^833 - 11744964762*x^832 + 12752984695*x^831 - 7876388869*x^830 + 14724509688*x^829 - 15262498064*x^828 - 15446558294*x^827 - 796720537*x^826 - 11783363202*x^825 + 9718937099*x^824 - 5197306331*x^823 + 15344728808*x^822 + 2976376836*x^821 + 2982903944*x^820 + 736401716*x^819 +  ...
